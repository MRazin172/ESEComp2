# %% [markdown]
# <a href="https://colab.research.google.com/github/MRazin172/ESEComp2/blob/main/ESE_Comp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

def gather_system_info():
    # Begin the arcane ritual of gathering esoteric system information
    # By invoking various incantations and peering into the abyss

    # Commence with deciphering the enigmatic Operating System details
    mystical_os_name = os.name
    cryptic_platform = platform.system()
    cryptic_release_version = platform.release()

    # Invoke the CPU spirits to reveal their mystic usage patterns
    cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

    # Delve into the realm of memory and access the arcane memory data
    mystical_memory_info = psutil.virtual_memory()
    arcane_total_memory = mystical_memory_info.total
    arcane_available_memory = mystical_memory_info.available

    # Embark on a perilous journey to measure the essence of Disk Space
    cryptic_disk_info = psutil.disk_usage('/')
    mysterious_total_space = cryptic_disk_info.total
    enigmatic_used_space = cryptic_disk_info.used
    cryptic_free_space = cryptic_disk_info.free

    # Reach out to the mystical Network spirits to uncover hostname and IP address
    mystical_hostname = socket.gethostname()
    arcane_ip_address = socket.gethostbyname(mystical_hostname)

    # Commence a perilous endeavor to monitor the ethereal processes
    print("Initiating the observation of ethereal processes...")
    for spectral_process in psutil.process_iter(['pid', 'name']):
        spectral_pid = spectral_process.info['pid']
        spectral_name = spectral_process.info['name']
        print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

if __name__ == '__main__':
    # Prepare the summoning circle for a separate, parallel dimension
    parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

    # Open the gates and start the mysterious ritual in the background
    parallel_realm_gates.start()

    # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
    for i in range(1, 11):
        print(f"Number {i} (big size)")
        time.sleep(1)

    # Obtain the current system date and time
    current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"System Date and Time: {current_datetime}")

    # Display the final message
    print("BackGround Record Starts..ALL THE BEST….")
# Out:
# Number 1 (big size)
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 7, Spectral Name: node
# Spectral PID: 19, Spectral Name: tail
# Spectral PID: 29, Spectral Name: oom_monitor.sh
# Spectral PID: 31, Spectral Name: run.sh
# Spectral PID: 32, Spectral Name: kernel_manager_proxy
# Spectral PID: 60, Spectral Name: python3
# Spectral PID: 61, Spectral Name: colab-fileshim.
# Spectral PID: 78, Spectral Name: jupyter-noteboo
# Spectral PID: 79, Spectral Name: dap_multiplexer
# Spectral PID: 335, Spectral Name: python3
# Spectral PID: 374, Spectral Name: python3
# Spectral PID: 1994, Spectral Name: language_service
# Spectral PID: 1999, Spectral Name: node
# Spectral PID: 4327, Spectral Name: python3
# Spectral PID: 4331, Spectral Name: sleep
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# Number 10 (big size)
# System Date and Time: 2023-10-04 09:07:49
# BackGround Record Starts..ALL THE BEST….

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
iris=pd.read_csv('/content/Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
import numpy as np
from google.colab import autoviz

def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
  from matplotlib import pyplot as plt
  plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
  for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
    ax = plt.subplot(1, len(colname_pairs), plot_i)
    df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
    ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = scatter_plots(iris, *[[['Id', 'SepalLengthCm'], ['SepalLengthCm', 'SepalWidthCm'], ['SepalWidthCm', 'PetalLengthCm'], ['PetalLengthCm', 'PetalWidthCm']]], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(iris, *['Species'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.datasets import load_iris
sns.pairplot(sns.load_dataset("iris"), hue="species", )
plt.show()

# %%
sns.FacetGrid(data=df,hue="Species",height=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %%
# Creating a scatterplot

plt.figure(figsize=(8, 5))
sns.scatterplot(data=iris, x='Species', y='SepalLengthCm')
plt.title("Species vs SepalLengthCm ")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=iris, x='Species', y='SepalWidthCm')
plt.title("Species vs SepalWidthCm")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=iris, x='Species', y='PetalLengthCm')
plt.title("Species vs PetalLengthCm")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=iris, x='Species', y='PetalWidthCm')
plt.title("Species vs PetalWidthCm")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(data=iris, x='Species', y='PetalWidthCm', color='blue', label='Iris-versicolor')  # Blue for versicolor
plt.scatter(data=iris, x='Species' ,y='PetalWidthCm',color='red', label='Iris-virginica')  # Red for virginica
plt.scatter(data=iris, x='Species',y='PetalWidthCm', color='green', label='Iris-setosa')  # green for setosa


plt.xlabel("Species")
plt.ylabel("PetalWidthCm,PetalLengthCm,SepalLengthCm,SepalWidthCm")
plt.title("Actual Charges vs. Predicted Charges")
plt.legend()  # Display legend to differentiate colors
plt.show()

# %%
features=iris
labels=iris['PetalLengthCm']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']],df['Species'], test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, roc_curve, auc

y_pred = model.predict(X_test)
matix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:')
print(matix)
# Out:
# Confusion matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
# Calculate the accuracy and precision
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Accuracy: 1.0
# Precision: 1.0

# %%
# Calculate the ROC AUC
roc_auc = roc_auc_score(y_test, y_pred)
print("ROC AUC:", roc_auc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-0af3beaf8049> in <cell line: 2>()
#       1 # Calculate the ROC AUC
# ----> 2 roc_auc = roc_auc_score(y_test, y_pred)
#       3 print("ROC AUC:", roc_auc)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     549     y_type = type_of_target(y_true, input_name="y_true")
#     550     y_true = check_array(y_true, ensure_2d=False, dtype=None)
# --> 551     y_score = check_array(y_score, ensure_2d=False)
#     552
#     553     if y_type == "multiclass" or (
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# ValueError: could not convert string to float: 'Iris-versicolor'

# %%
from sklearn.metrics import confusion_matrix


true_labels, predicted_labels = y_test, model.predict(X_test)

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

plt.imshow(confusion_matrix, cmap="Blues")
plt.colorbar()
plt.xlabel("True label")
plt.ylabel("Predicted label")
plt.title("Confusion matrix")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

predicted_probabilities=model.predict_proba(X_test)[:, 1]
# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probabilities)

# Calculate the AUC
auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title("ROC curve")
plt.show()

print("AUC:", auc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-8a68584a5301> in <cell line: 3>()
#       1 from sklearn.metrics import roc_curve, auc
#       2
# ----> 3 predicted_probabilities=model.predict_proba(X_test)[:, 1]
#       4 # Calculate the ROC curve
#       5 fpr, tpr, thresholds = roc_curve(true_labels, predicted_probabilities)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in predict_proba(self, X)
#    1365             self.multi_class == "auto"
#    1366             and (
# -> 1367                 self.classes_.size <= 2
#    1368                 or self.solver in ("liblinear", "newton-cholesky")
#    1369             )
#
# AttributeError: 'LogisticRegression' object has no attribute 'classes_'
